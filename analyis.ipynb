# %% [markdown]
# # Introduction to Digital Forensics - Assignment 1
# ### Data used 💽
# The group collected 100 listings in total from the Vice Market on the dark web.
#
# The focus was to collect data in a objective manner. This was done by choosing random listings listed on the site that were recommended. The listings recommended were most often from sellers with many reviews and sales. These sellers are the good and reliable sellers on the site.
#
# The data is checked for duplicates before generating the graphs. Data collected contains a column called 'Listing ID'. This is a unique identifier for a listing and it generated from the URL in the Excel file. In this Notebook we check whether there are duplicate Listing ID's in the dataset and point out where the duplicates are located so we can exchange them for new, non duplicated listings, to improve the quality of the data and analysis.
#
# ### Results generated in this Jupyter Notebook
# - Duplicate listings in the dataset
# - Top 10 sellers based on amount of listings on Vice City Market
# - Top 10 highest priced listings on Vice City Market
# - Ratio of legal/illegal/depends listings
# - Top 3 categories with the most listings
#
# ### Other assignment questions answered in this Jupyter Notebook
# - Most suprising products/posts
# - Vendors investigated
# - Three vendors the police should investigate
#
# ### Made by group 1:
# - Simge Bilen       s2532239
# - Mark Boom         s2552469
# - Tom Essers        s2484765
# - Baran Gülbey      s2616394
# - Jelmer Hofman     s2460653
# - Stijn Schuurman   s2620162

# %% [markdown]
# <img src="vicecity.png" width="500" />

# %%
# Install all required dependencies
# !pip3 install pandas
# !pip3 install openpyxl
# !pip3 install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# Load all dependencies
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load and initialize the Excel file
file = 'BlackMarketFinal.xlsx'

# %% [markdown]
# ## Prints a table of duplicates when there are duplicates Listing ID's in the dataset

# %%
df = pd.read_excel(file, usecols=['Listing ID'])
df[df.duplicated(['Listing ID'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [Listing ID]
# Index: []

# %% [markdown]
# As can be seen there are not any duplicate listing ID's in our datasheet.

# %% [markdown]
# # Top 10 sellers with the most listing on Vice City Black Market 📊

# %%
# Top 10 sellers with the most listing on Vicy City Black Market
df = pd.read_excel(file, usecols=['Seller'])
df.value_counts().head(10).plot.bar(color='green')
plt.title('Top 10 sellers based on amount of listings on Vice City Market')
plt.ylabel('Amount of listings')
plt.show()

# %% [markdown]
# In this graph we displayed the top 10 sellers based on the amount of listings they have within our datasheet. MiamiVice is clearly the biggest, within our 100 products they are the vendor for 18 of them, and they at the same time are also the biggest on the whole market. Trusteelucky is the second biggest with 9 products and Psychonauta02 is the third biggest with 6. These three vendors make up the Top 3 in our data sheet.

# %% [markdown]
# # Top 10 highest priced products 📊

# %%
# Top 10 highest priced products
df = pd.read_excel(file, usecols=['Title', 'Price'], index_col=0)
df.sort_values('Price', ascending=False).head(10).plot.bar(color='green')
plt.title('Top 10 highest priced listings on Vice City Market')
plt.xlabel(df.columns[0])
plt.ylabel('Price of listing')
plt.show()

# %% [markdown]
# This graph is not particulary for the assignment however we wanted to add this as an extra analysis. We were curious what the top 10 most expensive products would look like. As can be seen from the graph the 1lb of pure crystal meth is the most expensive, this is quite obvious because 1lb is very much especially for a hard drug. We could see that expensive listings on ViceCity were on in most cases in the category of drugs. ViceCity also had alot of 'courses'/'education', for example e-books and video lectures explaining certain (il)legal activities, these listings were in general less than 20 dollars and in most cases under 10 dollars.

# %% [markdown]
# # Top 3 categories with the most listings 📊

# %%
# Top 3 categories with the most listings
df = pd.read_excel(file, usecols=['Category'])
df.value_counts().head(10).plot.bar(color='green')
plt.title('Top 3 categories with the most listings')
plt.ylabel('Amount of listings')
plt.show()

# %% [markdown]
# We divided all the products within 9 categories, this way we could see which categories come more often than the other. As can be seen from the graph drugs is the most common listing on ViceCity. On a close second place we have the category courses and education. Software is third.

# %% [markdown]
# # Ratio of legal/illegal/depends listings 📊

# %%
# Ratio of legal/illegal/depends listings
df = pd.read_excel(file, usecols=['Legal?'])
df.value_counts().head(10).plot.bar(color='green')
plt.title('Ratio of legal/illegal/depends listings')
plt.ylabel('Amount of listings')
plt.show()

# %% [markdown]
# For all listings we said if they were illegal, legal or if it depends on the scenario (consent and intention). As can be seen most of the products were illegal, this is because alot of the listings are in the category of drugs and they are illegal in most countries especially the hard drugs that are being sold alot on the ViceCity market. Depends is in a close second place, this is because a lot of products can be used illegaly or legal, it depends on the consent and the intention of the user.

# %% [markdown]
# # Most suprising listings
# While browsing the darkweb market Vice City, we found alot of products that caught our attention and suprised us. From the biggest variety of edible sorts to hundreds of e-Books learning the reader about every illegal activity imaginable. We found that Vice City had a lot of different categories which made searching easier way easier than other darkweb markets.
# Below we listed the five products that suprised us the most:
# 1. Skittle flavoured crystal meth - something that sounds funny but apparently it is something very popular within the drug community.
# 2. TESTOSTERONE ENENTHATE 250 MG/ML 10 ML MONSTERLAB - Pure testerone, unknown for what use, suprised us very much.
# 3. Kettle Corn POTCORN/POPCORN Official - popcorn is not something we imagine when thinking of edibles.
# 4. 10 xmonero silent miner mine xmr using infected pc - Selling infected pc's for the use of mining Monero, or could be used to set up a Botnet.
# 5. Distillation kit - laboratory glass - borosilicate 3.3 - A whole brewing set in hindsight is pretty obvious to find on a darkweb market, however it still suprised us in the moment.

# %% [markdown]
# # Vendors investigated
# On the darkweb market Vice City there are a lot of different vendors that are selling there products. From the 100 sample of our analysis we found 54 different vendors, and in which twelve vendors had more than two products in our list. SocialMedia and NikeTeam are both in the Top 10 with 2 products each (and also the others with 2 products however they got filtered out). DutchDragons, Sixandeight and Monsterlabstore come in at position 6 with 3 products each. Monsterlabscore came to our attention because they have a pretty big amount of sales with 104, however their feedback score is 99! They are very reliable place to buy steroids as they only sell steroid products
#
# Safety1st and Flexowned sit at position nr. 4 with 4 products each. Flexowned has a lot of sales on Vice City, 356 in total and he received a feedback score of 95 from 156 users which means he is a very reliable vendor selling illegal courses and stolen user data.
#
# The top 3 consists of Psychonauta02 at nr. 3 with 6 products in total, he or she only sells drugs and also brewing sets with high quality glass instruments.
#
# Number 2 is Trusteelucky with 9 products in total out of our 100. He almost does not sell any drugs, in general he sells e-Book courses which teaches the reader all kinds of illegal activities and some fraud. Trusteelucky has sold 806 products on the Vice City market, he received a feedback score of 92 (which is very positive) from 541 user feedbacks. He has more than a hundred products on Vice City. Trusteelucky is also active on multiple darkweb websites, not only vice city.
#
# The biggest vendor from our analysis, and at the same time the biggest on the whole Vice City market, is **MiamiVice**, with a whopping 18 out of 100 products. They have the most listings on Vice City, 990 in total, which is more than 30 pages on the market. MiamiVice sells all sorts of varying products, but a big percentage of their listings are courses/education on varying illegal activities. They also sell alot of software including all sorts of keyloggers, neighbour wifi hacking software, etc. MiamiVice has 2965 sales on MiamiCity, and with such a big amount of sales they still have feedback score of 96 which means that they are very very reliable. 1348 users have left feedback on their profile. They provide multiple services for example: instant delivery, a bonus after giving positive feedback and 100% that the software/method is working, if it is not working MiamiVice provides you with a coupon to choose 5 items from his shop!
#
# A different vendor we found was GoldApple, they have only 2 listings in our list which technically also puts them in our Top 10. However we mention the vendor GoldApple because they have "All our products are for educational purpose only." in their biography, which perfectly goes along with the 'depends' illegal or legal debate. GoldApple has almost a thousand sales with a very good feedback score of 97, by selling only 'legal' products in a 'illegal' (not actually, depends) darkweb marketplace.
#
# We provided screenshots from several big vendors down below, including the two biggest: MiamiVice and Trusteelucky.

# %% [markdown]
# <img src="Vendor_1_Miami_Vice.png" width="500" /> <img src="Vendor_2_Trusteelucky.png" width="500"/>
# <img src="Flexowned.PNG" width="500" /> <img src="Monsterlabstore.PNG" width="500"/>
# <img src="Goldapple.PNG" width="500" />

# %% [markdown]
# # Conclusion
#
# ### Vendors that should be investigated by the Police
# We identified three vendors that the police should further investigate.
# - MiamiVice: For obvious reasons this vendor should be investigated by the police. They are the biggest on the market, have alot of sales, have 990 listings at the moment, have a high feedback score and ofcourse they sell alot of illegal products. As it seems they are not active on any other markets.
# - TrusteeLucky: This vendor is not the biggest on Vice City, however they could be one of the biggest vendors on the whole darkweb. They have been active since 2018 and have more than 10.000 sales on multiple sites all over the darkweb. They say that they are specialized in Carding, Paypal frauds, stolen credit card information (fullz), fraud in general, and general goods.
# - Monsterlabstore: With a very high feedback score this could very well mean that this has a very big chance to be an actual seller. They sell high profile illegal steroids which are very illegal. They are also active on other darkweb marketplaces where they also have a high feedback score. That is why the police should investigate them.
#
# ### Team
# Black market analysis was a great success within the research group. The group members came from various expertises and all had a different connection to the black market. One ordered already once from the black market, the other was very intrigued what it had to offer and did a lot of searching on the market, and one also had never really looked into the black market at all.
#
# Every single groupmember managed to go through the process of registering and logging in to the Vicy City black market, find 15+ unique listings, and entering it in the Excel file that we forged together. Later data analysis was conducted on the data in the Excel file and results were displayed. The results from the analysis sparked conversations within the group, which commonly confirmed speculations already made during collection. After the collection and discussing the results every group member managed to gain a good understanding how a black market functions with the Tor Browser, .union websites, slow connections, and a load of illegal products.
