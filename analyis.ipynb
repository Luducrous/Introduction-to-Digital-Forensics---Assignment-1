# %% [markdown]
# # Introduction to Digital Forensics - Assignment 1
# ### Data used 💽
# The group collected 100 listings in total from the Vicy Market on the dark web.
#
# The focus was to collect data in a objective manner. This was done by choosing random listings listed on the site that were recommended. The listings recommended were most often from sellers with many reviews and sales. These sellers are the good and reliable sellers on the site.
#
# The data is checked for duplicates before generating the graphs. Data collected contains a column called 'Listing ID'. This is a unique identifier for a listing and it generated from the URL in the Excel file. In this Notebook we check whether there are duplicate Listing ID's in the dataset and point out where the duplicates are located so we can exchange them for new, non duplicated listings, to improve the quality of the data and analysis.
#
# ### Results generated in this Jupyter Notebook
# - Duplicate listings in the dataset
# - Top 10 sellers based on amount of listings on Vice City Market
# - Top 10 highest priced listings on Vice City Market
# - Ratio of legal/illegal/depends listings
# - Top 3 categories with the most listings

# %%
# Install all required dependencies
# !pip3 install pandas
# !pip3 install openpyxl
# !pip3 install matplotlib
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/site-packages (1.5.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/site-packages (from pandas) (2022.2.1)
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.9/site-packages (from pandas) (1.23.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.9/site-packages (3.0.10)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.9/site-packages (from openpyxl) (1.1.0)
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/site-packages (3.6.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.9/site-packages (from matplotlib) (1.23.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/site-packages (from matplotlib) (4.37.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621

# %%
# Load all dependencies
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load and initialize the Excel file
file = 'Black Market analysis - Vice City Market.xlsx'

# %% [markdown]
# ## Prints a table of duplicates when there are duplicates Listing ID's in the dataset

# %%
df = pd.read_excel(file, usecols=['Listing ID'])
df[df.duplicated(['Listing ID'], keep=False)]
# Out:
#           Listing ID
# 11  05rMSJG6B9qCUYDG
# 33  05rMSJG6B9qCUYDG
# 41  0DOSb7LzjPhJnjUu
# 86  0DOSb7LzjPhJnjUu

# %% [markdown]
# # Top 10 sellers with the most listing on Vicy City Black Market 📊

# %%
# Top 10 sellers with the most listing on Vicy City Black Market
df = pd.read_excel(file, usecols=['Seller'])
df.value_counts().head(10).plot.bar(color='green')
plt.title('Top 10 sellers based on amount of listings on Vice City Market')
plt.ylabel('Amount of listings')
plt.show()

# %% [markdown]
# # Top 10 highest priced products 📊

# %%
# Top 10 highest priced products
df = pd.read_excel(file, usecols=['Title', 'Price'], index_col=0)
df.sort_values('Price', ascending=False).head(10).plot.bar(color='green')
plt.title('Top 10 highest priced listings on Vice City Market')
plt.xlabel(df.columns[0])
plt.ylabel('Price of listing')
plt.show()

# %% [markdown]
# # Top 3 categories with the most listings 📊

# %%
# Top 3 categories with the most listings
df = pd.read_excel(file, usecols=['Category'])
df.value_counts().head(10).plot.bar(color='green')
plt.title('Top 3 categories with the most listings')
plt.ylabel('Amount of listings')
plt.show()

# %% [markdown]
# # Ratio of legal/illegal/depends listings 📊

# %%
# Ratio of legal/illegal/depends listings
df = pd.read_excel(file, usecols=['Legal?'])
df.value_counts().head(10).plot.bar(color='green')
plt.title('Ratio of legal/illegal/depends listings')
plt.ylabel('Amount of listings')
plt.show()
